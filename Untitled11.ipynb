# %% [markdown]
# <a href="https://colab.research.google.com/github/JOJO0308/Introduction-to-Computers/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
f = open('iris.txt','r')
a = f.read()
for line in f:
  print(line)
f.seek(0)
for line in f:
  print(line)
def cal_pccs(x, y, n):
    sum_xy = np.sum(np.iris.txt(Sepal_Length*Sepal_Width))
    sum_x = np.iris.txt(np.sum(Sepal_Length))
    sum_y = np.iris.txt(np.sum(Sepal_Width))
    sum_x2 = np.iris.txt(np.sum(Sepal_Length*Sepal_Length))
    sum_y2 = np.iris.txt(np.sum(Sepal_Width*Sepal_Width))
    pcc = (n*sum_xy-sum_x*sum_y)/np.sqrt((n*sum_x2-sum_x*sum_x)*(n*sum_y2-sum_y*sum_y))
    return pcc
f.close()
# Out:
# iris	Group	Sepal_Length	Sepal_Width	Petal_Length	Petal_Width
#
# setosa	0	5.1	3.5	1.4	0.2
#
# setosa	0	4.9	3	1.4	0.2
#
# setosa	0	4.7	3.2	1.3	0.2
#
# setosa	0	4.6	3.1	1.5	0.2
#
# setosa	0	5	3.6	1.4	0.2
#
# setosa	0	5.4	3.9	1.7	0.4
#
# setosa	0	4.6	3.4	1.4	0.3
#
# setosa	0	5	3.4	1.5	0.2
#
# setosa	0	4.4	2.9	1.4	0.2
#
# setosa	0	4.9	3.1	1.5	0.1
#
# setosa	0	5.4	3.7	1.5	0.2
#
# setosa	0	4.8	3.4	1.6	0.2
#
# setosa	0	4.8	3	1.4	0.1
#
# setosa	0	4.3	3	1.1	0.1
#
# setosa	0	5.8	4	1.2	0.2
#
# setosa	0	5.7	4.4	1.5	0.4
#
# setosa	0	5.4	3.9	1.3	0.4
#
# setosa	0	5.1	3.5	1.4	0.3
#
# setosa	0	5.7	3.8	1.7	0.3
#
# setosa	0	5.1	3.8	1.5	0.3
#
# setosa	0	5.4	3.4	1.7	0.2
#
# setosa	0	5.1	3.7	1.5	0.4
#
# setosa	0	4.6	3.6	1	0.2
#
# setosa	0	5.1	3.3	1.7	0.5
#
# setosa	0	4.8	3.4	1.9	0.2
#
# setosa	0	5	3	1.6	0.2
#
# setosa	0	5	3.4	1.6	0.4
#
# setosa	0	5.2	3.5	1.5	0.2
#
# setosa	0	5.2	3.4	1.4	0.2
#
# setosa	0	4.7	3.2	1.6	0.2
#
# setosa	0	4.8	3.1	1.6	0.2
#
# setosa	0	5.4	3.4	1.5	0.4
#
# setosa	0	5.2	4.1	1.5	0.1
# ...
